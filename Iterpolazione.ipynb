# %%
import numpy as np
import pandas as pd

# %%
def Interpolation(Y, h, r, i, c = 1):

    f = c*Y[i]
    if j < len(Y):    
        c = c(r-(i-1))/i
        dif = DELTA(Y)

# %%
def DELTA(Y):
    
    for i in range(len(Y)-1):
        Y[i] = Y[i+1] - Y[i]
    DY = Y[:-1]
    return DY

# %%
df = pd.read_excel('Dati.xlsx')
y = df['Y'].to_numpy()
x = df['X'].to_numpy()
i = np.argmin(y)
h = (x[len(x)-1] - x[0])/(len(x)-1)
r = 1/2
m = len(y) - 1
m
# Out:
# 16

# %%
#prendo x_5 e x_6
